# %%
import numpy as np
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import community
import collections
import powerlaw

from helper import *

# %%
trades_df2016, trades_df2011, trades_df2006, trades_df2001, trades_Total, gasTrades_Total, coalTrades_Total, oilTrades_Total = get_data()

# %%
exports_imports_plot(coalTrades_Total, 'Coal')
exports_imports_plot(gasTrades_Total, 'Gas')
exports_imports_plot(oilTrades_Total, 'Oil')

# %%
uniqueExporterISO3 =trades_Total['Exporter ISO3'].unique()
mapEx2Row = dict(zip(uniqueExporterISO3, range(0,len(uniqueExporterISO3))))

# %%
gasDegree = genDegreeMatrix4AllYears(gasTrades_Total, mapEx2Row)
coalDegree = genDegreeMatrix4AllYears(coalTrades_Total, mapEx2Row)
oilDegree = genDegreeMatrix4AllYears(oilTrades_Total, mapEx2Row)
totalDegree = genDegreeMatrix4AllYears(trades_Total, mapEx2Row)

# %%
in_out_degree_plot(coalDegree, mapEx2Row, 'Coal')

# %% [markdown]
# ### The jump in exports around 2004 can be potentially explained by:
# According to the U.S. Coal Supply and Demand: 2004 Review's Exports and Imports section:
#
# "The Asian market for U.S. metallurgical coal which virtually did not exist for the last 3 years, came roaring back to levels not seen since the late 1990's."
#
# https://www.eia.gov/coal/review/pdf/feature04.pdf

# %% [markdown]
# ## Power Law Test:
#
# Lets see how well our data matches the power law distribution. Is this network "Scale Free"?

# %%
plotting_power_compared2_expontial(gasDegree, oilDegree, coalDegree, totalDegree, save=True)
# Out:
# Calculating best minimal value for power law fit
# /anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# /anaconda3/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: divide by zero encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# ...

# %%
plt.show()

# %%
connectivity_plot(gasDegree, oilDegree, coalDegree, totalDegree)
