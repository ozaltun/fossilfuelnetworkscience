# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
root = '/Users/boraozaltun/Dropbox (MIT)/Data/Trade/general_equilibrium_gravity/GTAP/input/{}'

# %%
files = ['basedata.csv', 'gview.csv', 'TSTRADE.csv']

# %%
# Pandas can't figure it out, need to clean
TSTRADE = pd.read_csv(root.format(files[2]), header=0)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
TSTRADE
# Out:
#               !Header: VTTS  \
# TRAD_COMM REG           REG
# ofd       aus           aus
# b_t       aus           aus
# ome       aus           aus
# v_f       nzl           aus
# ocr       nzl           aus
# ctl       nzl           aus
# oap       nzl           aus
# wol       nzl           aus
# fsh       nzl           aus
# col       nzl           aus
# oil       nzl           aus
# gas       nzl           aus
# omn       nzl           aus
# cmt       nzl           aus
# omt       nzl           aus
# vol       nzl           aus
# mil       nzl           aus
# sgr       nzl           aus
# ofd       nzl           aus
# b_t       nzl           aus
# tex       nzl           aus
# wap       nzl           aus
# lea       nzl           aus
# lum       nzl           aus
# ppp       nzl           aus
# p_c       nzl           aus
# crp       nzl           aus
# nmm       nzl           aus
# i_s       nzl           aus
# ...                     ...
# otn       can           xtw
# ome       can           xtw
# crp       usa           xtw
# ome       usa           xtw
# v_f       chl           xtw
# ofd       bel           xtw
# crp       bel           xtw
# ome       bel           xtw
#           fra           xtw
# lum       deu           xtw
# ppp       deu           xtw
# crp       deu           xtw
# mvh       deu           xtw
# ele       deu           xtw
# ome       deu           xtw
# mil       nld           xtw
# crp       nld           xtw
# mvh       nld           xtw
# ele       nld           xtw
# ome       nld           xtw
# omt       pol           xtw
# fmp       esp           xtw
# ele       esp           xtw
# ome       esp           xtw
# mvh       swe           xtw
# ome       che           xtw
# crp       nga           xtw
# nmm       zaf           xtw
# fmp       zaf           xtw
# ome       zaf           xtw
#
#                dimensions: TRAD_COMM*REG*REG*YEAR [57*134*134*15]  \
# TRAD_COMM REG                                               YEAR
# ofd       aus                                              Y1995
# b_t       aus                                              Y1995
# ome       aus                                              Y1995
# v_f       nzl                                              Y1995
# ocr       nzl                                              Y1995
# ctl       nzl                                              Y1995
# oap       nzl                                              Y1995
# wol       nzl                                              Y1995
# fsh       nzl                                              Y1995
# col       nzl                                              Y1995
# oil       nzl                                              Y1995
# gas       nzl                                              Y1995
# omn       nzl                                              Y1995
# cmt       nzl                                              Y1995
# omt       nzl                                              Y1995
# vol       nzl                                              Y1995
# mil       nzl                                              Y1995
# sgr       nzl                                              Y1995
# ofd       nzl                                              Y1995
# b_t       nzl                                              Y1995
# tex       nzl                                              Y1995
# wap       nzl                                              Y1995
# lea       nzl                                              Y1995
# lum       nzl                                              Y1995
# ppp       nzl                                              Y1995
# p_c       nzl                                              Y1995
# crp       nzl                                              Y1995
# nmm       nzl                                              Y1995
# i_s       nzl                                              Y1995
# ...                                                          ...
# otn       can                                              Y2009
# ome       can                                              Y2009
# crp       usa                                              Y2009
# ome       usa                                              Y2009
# v_f       chl                                              Y2009
# ofd       bel                                              Y2009
# crp       bel                                              Y2009
# ome       bel                                              Y2009
#           fra                                              Y2009
# lum       deu                                              Y2009
# ppp       deu                                              Y2009
# crp       deu                                              Y2009
# mvh       deu                                              Y2009
# ele       deu                                              Y2009
# ome       deu                                              Y2009
# mil       nld                                              Y2009
# crp       nld                                              Y2009
# mvh       nld                                              Y2009
# ele       nld                                              Y2009
# ome       nld                                              Y2009
# omt       pol                                              Y2009
# fmp       esp                                              Y2009
# ele       esp                                              Y2009
# ome       esp                                              Y2009
# mvh       swe                                              Y2009
# ome       che                                              Y2009
# crp       nga                                              Y2009
# nmm       zaf                                              Y2009
# fmp       zaf                                              Y2009
# ome       zaf                                              Y2009
#
#                description: NTSTRD(TRAD_COMM:REG:REG:LYEAR)
# TRAD_COMM REG                                         Value
# ofd       aus                                             1
# b_t       aus                                             1
# ome       aus                                             1
# v_f       nzl                                            32
# ocr       nzl                                             8
# ctl       nzl                                            45
# oap       nzl                                             8
# wol       nzl                                            36
# fsh       nzl                                             9
# col       nzl                                             5
# oil       nzl                                           124
# gas       nzl                                             2
# omn       nzl                                             2
# cmt       nzl                                            17
# omt       nzl                                             4
# vol       nzl                                             1
# mil       nzl                                            80
# sgr       nzl                                             4
# ofd       nzl                                           180
# b_t       nzl                                            15
# tex       nzl                                           117
# wap       nzl                                            85
# lea       nzl                                            75
# lum       nzl                                           248
# ppp       nzl                                           302
# p_c       nzl                                            14
# crp       nzl                                           332
# nmm       nzl                                            11
# i_s       nzl                                            57
# ...                                                     ...
# otn       can                                             1
# ome       can                                             1
# crp       usa                                             1
# ome       usa                                             1
# v_f       chl                                             2
# ofd       bel                                             1
# crp       bel                                             1
# ome       bel                                             1
#           fra                                             3
# lum       deu                                             1
# ppp       deu                                             4
# crp       deu                                             2
# mvh       deu                                             3
# ele       deu                                            33
# ome       deu                                            57
# mil       nld                                             2
# crp       nld                                             1
# mvh       nld                                             1
# ele       nld                                             1
# ome       nld                                             2
# omt       pol                                             1
# fmp       esp                                             4
# ele       esp                                             1
# ome       esp                                             1
# mvh       swe                                             1
# ome       che                                             1
# crp       nga                                            10
# nmm       zaf                                             2
# fmp       zaf                                             2
# ome       zaf                                             1
#
# [1393820 rows x 3 columns]

# %%
import csv

data_dict = {}
with open(root.format(files[2])) as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for row in readCSV:
        if 'Header' in row[0]:
            key = row[2].split('description: ')[1]
            data_dict[key] = {}
            data_dict[key]['header']= row
            data_dict[key]['data'] = []
            print(row)
        else:
            data_dict[key]['data'].append(row)
# Out:
# ['!Header: VTTS', ' dimensions: TRAD_COMM*REG*REG*YEAR [57*134*134*15]', ' description: NTSTRD(TRAD_COMM:REG:REG:LYEAR)']

# %%
acronym_list = []
for i in data_dict.keys():
    print(i)
    data_dict[i]['header'][0] = data_dict[i]['header'][0].split('!Header: ')[1]
# Out:
# NTSTRD(TRAD_COMM:REG:REG:LYEAR)

# %%
root2 = '/Users/boraozaltun/Dropbox (MIT)/Data/Trade/general_equilibrium_gravity/GTAP/output/TSTRADE/{}'

# %%
## Just a naive check that there are nnon issues in turning the data into pandas
for i in data_dict.keys():
    data_dict[i]['data_df'] = pd.DataFrame(data_dict[i]['data'])

# %%
header_list = []
for i in data_dict.keys():
    data_dict[i]['data_df'].to_csv(root2.format(i+'.csv'))
    header_list.append(data_dict[i]['header'])

# %%
pd.DataFrame(header_list).to_csv(root2.format('Data Description.csv'))

# %%
del data_dict
